# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pdp
import pprint
import datetime

import pickle

from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('../data/input/train.csv')
test = pd.read_csv('../data/input/test.csv')
sample_sub = pd.read_csv('../data/input/sample_submit.csv', header=None, names=['id', 'mpg'])

train_test = pd.concat([train, test], ignore_index=True, sort=False)

# %% [markdown]
# ## 前処理

# %%
# 平均値を計算するために欠損値をNanに変換し、horsepower全体をfloatに変換する
train_test['horsepower'].replace('?', np.nan, inplace=True)
train_test['horsepower'] = train_test['horsepower'].astype(float)

# %%
train_test['car name'] = train_test['car name'].str.replace('vw', 'volkswagen')
train_test['car name'] = train_test['car name'].str.replace('vokswagen', 'volkswagen')
train_test['car name'] = train_test['car name'].str.replace('toyouta', 'toyota')
train_test['car name'] = train_test['car name'].str.replace('chevy', 'chevrolet')
train_test['car name'] = train_test['car name'].str.replace('datsun 200-sx', 'datsun 200sx')

train_test['car name'] = train_test['car name'].str.replace('datsun 210 mpg', 'datsun 210')
train_test['car name'] = train_test['car name'].str.replace('ford gran torino (sw)', 'ford gran torino')

# %%
train_test['car_brand'] = train_test['car name'].apply(lambda x: x.strip().split(' ')[0])

# %%
# car name毎のhorse powerの平均値を計算(nanは計算外)
name_hp_mean = train_test.groupby('car name').horsepower.mean()
df_hp_isnull = train_test[train_test['horsepower'].isnull()]

# nan位置のtrainデータのhorse powerを置換する
for i in df_hp_isnull.index:
    train_test.loc[i, 'horsepower'] = name_hp_mean[df_hp_isnull.loc[i, 'car name']]

# %%
tmp = train_test
test_treated = tmp[tmp['mpg'].isnull()].copy()
train_treated = tmp.dropna(subset=['mpg'], axis=0).copy()

# %%
display(train_treated)
display(test_treated)
# Out:
#       id        mpg  cylinders  displacement  horsepower  weight  \
# 0      0  23.059782          6           140       110.0    2815
# 1      3  17.674521          8           350       150.0    4456
# 2      4  17.136353          8           302       140.0    2774
# 3      7  22.664666          6           400        85.0    2190
# 4      9  17.872018          8           429       220.0    2245
# ..   ...        ...        ...           ...         ...     ...
# 495  981  22.798447          4           140       148.0    2835
# 496  983  35.173640          4            97        67.0    2234
# 497  994  17.825448          8           302       220.0    2774
# 498  995  28.545147          4            97       150.0    2130
# 499  997  36.011880          4            97       150.0    2300
#
#      acceleration  model year  origin                    car name  car_brand
# 0       17.977429          80       1                 dodge aspen      dodge
# 1       13.514535          72       1               dodge rampage      dodge
# 2       13.209912          79       1     mercury cougar brougham    mercury
# 3       15.196381          71       1  pontiac j2000 se hatchback    pontiac
# 4        9.621400          70       1            ford galaxie 500       ford
# ..            ...         ...     ...                         ...        ...
# 495     13.477573          82       1                datsun 200sx     datsun
# 496     17.542681          80       3            plymouth valiant   plymouth
# 497     15.177189          76       1           triumph tr7 coupe    triumph
# 498     13.324669          70       1                datsun pl510     datsun
# 499     15.364361          71       1              chevrolet nova  chevrolet
#
# [500 rows x 11 columns]
#       id  mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 500    1  NaN          4            98        67.0    2000     15.049795
# 501    2  NaN          4            97        90.0    2720     15.339172
# 502    5  NaN          4            90        75.0    2807     17.821599
# 503    6  NaN          4           140       110.0    2807     13.780354
# 504    8  NaN          4           121        85.0    3070     13.688921
# ..   ...  ...        ...           ...         ...     ...           ...
# 995  992  NaN          4           225       105.0    3870     15.376311
# 996  993  NaN          4           140       112.0    2720     13.616843
# 997  996  NaN          8           318       110.0    2774     13.272636
# 998  998  NaN          4            90        75.0    2807     17.792560
# 999  999  NaN          4            90        69.0    2190     21.443561
#
#      model year  origin               car name  car_brand
# 500          81       1            peugeot 504    peugeot
# 501          79       1            dodge aspen      dodge
# 502          77       1  dodge monaco brougham      dodge
# 503          82       2  buick century limited      buick
# 504          73       2              saab 99le       saab
# ..          ...     ...                    ...        ...
# 995          76       1         chevrolet nova  chevrolet
# 996          82       1  buick century limited      buick
# 997          75       1               ford ltd       ford
# 998          77       1  dodge monaco brougham      dodge
# 999          72       2             ford pinto       ford
#
# [500 rows x 11 columns]

# %% [markdown]
# ## train, testの違いを確認する

# %% [markdown]
# ### car name, car_brand

# %%
for brand in np.sort(train_test['car_brand'].unique()):
    print(brand)
    print('train:')
    print(np.unique(train_treated.loc[train_treated['car_brand']==brand, 'car name'].values))
    print("test:")
    print(np.unique(test_treated.loc[test_treated['car_brand']==brand, 'car name'].values))
    print("\n")
# Out:
# amc
# train:
# ['amc ambassador dpl' 'amc gremlin' 'amc hornet' 'amc matador'
#  'amc pacer d/l' 'amc spirit dl']
# test:
# ['amc concord d/l' 'amc gremlin' 'amc hornet' 'amc matador'
#  'amc pacer d/l' 'amc spirit dl']
#
#
# audi
# train:
# ['audi 5000s (diesel)']
# test:
# ['audi 5000s (diesel)']
#
#
# buick
# train:
# ['buick century' 'buick century limited' 'buick lesabre custom'
#  'buick regal sport coupe (turbo)' 'buick skyhawk']
# test:
# ['buick century' 'buick century limited' 'buick lesabre custom'
#  'buick regal sport coupe (turbo)' 'buick skyhawk' 'buick skylark limited']
#
#
# capri
# train:
# ['capri ii']
# test:
# ['capri ii']
#
#
# chevrolet
# train:
# ['chevrolet caprice classic' 'chevrolet impala' 'chevrolet monza 2+2'
#  'chevrolet nova' 'chevrolet vega' 'chevrolet woody']
# test:
# ['chevrolet c20' 'chevrolet caprice classic'
#  'chevrolet chevelle malibu classic' 'chevrolet impala'
#  'chevrolet monte carlo s' 'chevrolet monza 2+2' 'chevrolet nova'
#  'chevrolet vega' 'chevrolet woody']
#
#
# datsun
# train:
# ['datsun 1200' 'datsun 200sx' 'datsun 210' 'datsun 510 (sw)' 'datsun 710'
#  'datsun 810 maxima' 'datsun pl510']
# test:
# ['datsun 200sx' 'datsun 210' 'datsun 510 (sw)' 'datsun 710'
#  'datsun 810 maxima' 'datsun f-10 hatchback' 'datsun pl510']
#
#
# dodge
# train:
# ['dodge aries se' 'dodge aspen' 'dodge colt' 'dodge coronet custom'
#  'dodge magnum xe' 'dodge monaco brougham' 'dodge omni' 'dodge rampage']
# test:
# ['dodge aries se' 'dodge aspen' 'dodge colt' 'dodge magnum xe'
#  'dodge monaco brougham' 'dodge omni' 'dodge rampage']
#
#
# fiat
# train:
# ['fiat 124 sport coupe' 'fiat 128']
# test:
# ['fiat 124 sport coupe' 'fiat 128']
#
#
# ford
# train:
# ['ford fairmont (man)' 'ford futura' 'ford galaxie 500' 'ford gran torino'
#  'ford gran torino (sw)' 'ford granada l' 'ford ltd' 'ford mustang ii 2+2'
#  'ford pinto']
# test:
# ['ford escort 4w' 'ford f108' 'ford fairmont' 'ford fairmont (man)'
#  'ford futura' 'ford galaxie 500' 'ford gran torino' 'ford ltd'
#  'ford mustang ii 2+2' 'ford pinto']
#
#
# hi
# train:
# ['hi 1200d']
# test:
# ['hi 1200d']
#
#
# honda
# train:
# ['honda civic 1300' 'honda civic 1500 gl']
# test:
# ['honda accord lx' 'honda civic 1300']
#
#
# mercury
# train:
# ['mercury capri 2000' 'mercury cougar brougham' 'mercury zephyr 6']
# test:
# ['mercury cougar brougham' 'mercury zephyr 6']
#
#
# oldsmobile
# train:
# ['oldsmobile cutlass ciera (diesel)']
# test:
# ['oldsmobile cutlass ciera (diesel)' 'oldsmobile delta 88 royale']
#
#
# opel
# train:
# ['opel 1900' 'opel manta']
# test:
# ['opel 1900' 'opel manta']
#
#
# peugeot
# train:
# ['peugeot 504' 'peugeot 505s turbo diesel']
# test:
# ['peugeot 504' 'peugeot 505s turbo diesel']
#
#
# plymouth
# train:
# ['plymouth champ' 'plymouth reliant' 'plymouth valiant']
# test:
# ['plymouth champ' 'plymouth reliant' 'plymouth valiant'
#  'plymouth volare premier v8']
#
#
# pontiac
# train:
# ['pontiac astro' 'pontiac j2000 se hatchback' 'pontiac lemans v6']
# test:
# ['pontiac astro' 'pontiac j2000 se hatchback' 'pontiac lemans v6']
#
#
# renault
# train:
# ['renault lecar deluxe']
# test:
# ['renault lecar deluxe']
#
#
# saab
# train:
# ['saab 99le']
# test:
# ['saab 99le']
#
#
# toyota
# train:
# ['toyota corolla' 'toyota corona mark ii (sw)' 'toyota mark ii'
#  'toyota starlet']
# test:
# ['toyota corolla' 'toyota corona liftback' 'toyota corona mark ii (sw)'
#  'toyota mark ii']
#
#
# triumph
# train:
# ['triumph tr7 coupe']
# test:
# ['triumph tr7 coupe']
#
#
# volkswagen
# train:
# ['volkswagen dasher' 'volkswagen jetta' 'volkswagen rabbit'
#  'volkswagen rabbit custom' 'volkswagen rabbit custom diesel']
# test:
# ['volkswagen dasher' 'volkswagen rabbit' 'volkswagen rabbit custom']
#
#
# volvo
# train:
# []
# test:
# ['volvo 145e (sw)']

# %%
train_treated['pwr'] = train_treated['weight'] / train_treated['horsepower']
test_treated['pwr'] = test_treated['weight'] / test_treated['horsepower']
display(train_treated.head())
display(test_treated.head())
# Out:
#    id        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   0  23.059782          6           140       110.0    2815     17.977429
# 1   3  17.674521          8           350       150.0    4456     13.514535
# 2   4  17.136353          8           302       140.0    2774     13.209912
# 3   7  22.664666          6           400        85.0    2190     15.196381
# 4   9  17.872018          8           429       220.0    2245      9.621400
#
#    model year  origin                    car name car_brand        pwr
# 0          80       1                 dodge aspen     dodge  25.590909
# 1          72       1               dodge rampage     dodge  29.706667
# 2          79       1     mercury cougar brougham   mercury  19.814286
# 3          71       1  pontiac j2000 se hatchback   pontiac  25.764706
# 4          70       1            ford galaxie 500      ford  10.204545
#      id  mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 500   1  NaN          4            98        67.0    2000     15.049795
# 501   2  NaN          4            97        90.0    2720     15.339172
# 502   5  NaN          4            90        75.0    2807     17.821599
# 503   6  NaN          4           140       110.0    2807     13.780354
# 504   8  NaN          4           121        85.0    3070     13.688921
#
#      model year  origin               car name car_brand        pwr
# 500          81       1            peugeot 504   peugeot  29.850746
# 501          79       1            dodge aspen     dodge  30.222222
# 502          77       1  dodge monaco brougham     dodge  37.426667
# 503          82       2  buick century limited     buick  25.518182
# 504          73       2              saab 99le      saab  36.117647

# %%
train_treated['car_name_code'] = LabelEncoder().fit_transform(train_treated['car name'])
train_treated['car_brand_code'] = LabelEncoder().fit_transform(train_treated['car_brand'])

test_treated['car_name_code'] = LabelEncoder().fit_transform(test_treated['car name'])
test_treated['car_brand_code'] = LabelEncoder().fit_transform(test_treated['car_brand'])

display(train_treated.head())
display(test_treated.head())
# Out:
#    id        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   0  23.059782          6           140       110.0    2815     17.977429
# 1   3  17.674521          8           350       150.0    4456     13.514535
# 2   4  17.136353          8           302       140.0    2774     13.209912
# 3   7  22.664666          6           400        85.0    2190     15.196381
# 4   9  17.872018          8           429       220.0    2245      9.621400
#
#    model year  origin                    car name car_brand        pwr  \
# 0          80       1                 dodge aspen     dodge  25.590909
# 1          72       1               dodge rampage     dodge  29.706667
# 2          79       1     mercury cougar brougham   mercury  19.814286
# 3          71       1  pontiac j2000 se hatchback   pontiac  25.764706
# 4          70       1            ford galaxie 500      ford  10.204545
#
#    car_name_code  car_brand_code
# 0             27               6
# 1             33               6
# 2             49              11
# 3             60              16
# 4             38               8
#      id  mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 500   1  NaN          4            98        67.0    2000     15.049795
# 501   2  NaN          4            97        90.0    2720     15.339172
# 502   5  NaN          4            90        75.0    2807     17.821599
# 503   6  NaN          4           140       110.0    2807     13.780354
# 504   8  NaN          4           121        85.0    3070     13.688921
#
#      model year  origin               car name car_brand        pwr  \
# 500          81       1            peugeot 504   peugeot  29.850746
# 501          79       1            dodge aspen     dodge  30.222222
# 502          77       1  dodge monaco brougham     dodge  37.426667
# 503          82       2  buick century limited     buick  25.518182
# 504          73       2              saab 99le      saab  36.117647
#
#      car_name_code  car_brand_code
# 500             58              14
# 501             31               6
# 502             34               6
# 503              8               2
# 504             68              18

# %%
train_treated.drop(['car name', 'car_brand'], axis=1, inplace=True)
test_treated.drop(['car name', 'car_brand'], axis=1, inplace=True)

# %%
dt = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S')

# train, test
train_treated.to_pickle(
    '../features/feature_train_' + dt + '_treated.pkl'
)
test_treated.to_pickle(
    '../features/feature_test_' + dt + '_treated.pkl'
)
